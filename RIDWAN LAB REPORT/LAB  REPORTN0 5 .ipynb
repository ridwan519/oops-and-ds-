# %% [markdown]
# <center>
#     <div style="
#         background: linear-gradient(90deg, #c83349, #622569);
#         padding: 30px 20px;
#         border-radius: 25px;
#         box-shadow: 0 7px 6px rgba(0, 0, 0, 0.3);
#         display: inline-block;
#         border: 2px solid #CCCCFF;
#         max-width: 90%;
#     ">
#         <span style="
#             font-size: 30px;
#             font-family: Cooper Black;
#             color: #FFBF00;
#             font-weight: bold;
#             letter-spacing: 1px;
#             text-shadow: 3px 1px 8px rgba(0, 0, 1, 0.6);
#         ">
#             Lab NO 5
#         </span>
#     </div>
# </center>

# %% [markdown]
# <span style="color: #000000;
# font-size: 44px;
# transition: color 0.3s;">&#x21DD; </span>
# <span style="color: #ff0000;
#     font-family: Arial Black;
# font-size: 35px; font-weight: bold;
# text-shadow: 0px 4px 2px rgb(0, 0, 0);">
#     Lab REPORT Tasks :</span>

# %% [markdown]
# ![LAB NO 5.PNG](attachment:69201cde-c4e9-486e-bb70-471f468634a6.PNG)

# %%
class Circle:
    def __init__(self, radius: float = 1.0):
        self._radius = radius

    @property
    def radius(self) -> float:
        return self._radius

    @radius.setter
    def radius(self, value: float):
        if value < 0:
            raise ValueError("Radius cannot be negative.")
        self._radius = value

    @property
    def area(self) -> float:
        import math
        return math.pi * self.radius ** 2

    @property
    def circumference(self) -> float:
        import math
        return 2 * math.pi * self.radius

    @property
    def diameter(self) -> float:
        return 2 * self.radius

    def cylinder_volume(self, height: float) -> float:
        return self.area * height

    def __repr__(self) -> str:
        return f"Circle(radius={self.radius})"

    def __str__(self) -> str:
        return f"Circle with radius {self.radius}"

# %%
# Create instances
inst_1 = Circle(5)
inst_2 = Circle(7)

# %%
# Print instances
print(inst_1)
print(inst_2)
# Out:
# Circle with radius 5
# Circle with radius 7

# %%
# Access __dict__ of the class
print(Circle.__dict__)
# Out:
# {'__module__': '__main__', '__doc__': '\n    Circle class to represent a circle with various properties and methods.\n\n    Attributes:\n        radius (float): The radius of the circle.\n    ', '__init__': <function Circle.__init__ at 0x0000027F35A59300>, 'radius': <property object at 0x0000027F35A8C1D0>, 'area': <property object at 0x0000027F35A8C130>, 'circumference': <property object at 0x0000027F35A8C180>, 'diameter': <property object at 0x0000027F35A8C220>, 'cylinder_volume': <function Circle.cylinder_volume at 0x0000027F35A59EE0>, '__repr__': <function Circle.__repr__ at 0x0000027F35A59F80>, '__str__': <function Circle.__str__ at 0x0000027F35A5A020>, '__dict__': <attribute '__dict__' of 'Circle' objects>, '__weakref__': <attribute '__weakref__' of 'Circle' objects>}

# %%
# Use vars on the class
print(vars(Circle))
# Out:
# {'__module__': '__main__', '__doc__': '\n    Circle class to represent a circle with various properties and methods.\n\n    Attributes:\n        radius (float): The radius of the circle.\n    ', '__init__': <function Circle.__init__ at 0x0000027F35A59300>, 'radius': <property object at 0x0000027F35A8C1D0>, 'area': <property object at 0x0000027F35A8C130>, 'circumference': <property object at 0x0000027F35A8C180>, 'diameter': <property object at 0x0000027F35A8C220>, 'cylinder_volume': <function Circle.cylinder_volume at 0x0000027F35A59EE0>, '__repr__': <function Circle.__repr__ at 0x0000027F35A59F80>, '__str__': <function Circle.__str__ at 0x0000027F35A5A020>, '__dict__': <attribute '__dict__' of 'Circle' objects>, '__weakref__': <attribute '__weakref__' of 'Circle' objects>}

# %%
# Access __dict__ of an object
print(inst_1.__dict__)
# Out:
# {'_radius': 5}

# %%
# Pass the class to help
help(Circle)
# Out:
# Help on class Circle in module __main__:
#
# class Circle(builtins.object)
#  |  Circle(radius: float = 1.0)
#  |
#  |  Circle class to represent a circle with various properties and methods.
#  |
#  |  Attributes:
#  |      radius (float): The radius of the circle.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, radius: float = 1.0)
#  |      Initialize the Circle object with a given radius.
#  |
#  |      Args:
#  |          radius (float, optional): The radius of the circle. Defaults to 1.0.
#  |
#  |  __repr__(self) -> str
#  |      Return an unambiguous string representation of the Circle object.
#  |
#  |      Returns:
#  |          str: A string representation of the Circle object.
#  |
#  |  __str__(self) -> str
#  |      Return a readable string representation of the Circle object.
#  |
#  |      Returns:
#  |          str: A readable string representation of the Circle object.
#  |
#  |  cylinder_volume(self, height: float) -> float
# ...

# %%
# Print doc-string and annotations
print(Circle.__doc__)
# Out:
#     Circle class to represent a circle with various properties and methods.
#
#     Attributes:
#         radius (float): The radius of the circle.

# %%
print(Circle.__init__.__annotations__)
# Out:
# {'radius': <class 'float'>}

# %%
print(Circle.cylinder_volume.__annotations__)

# %%
# Verify modified __init__ with default parameter
inst_3 = Circle()
print(inst_3)
