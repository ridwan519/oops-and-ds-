# %% [markdown]
# <center>
#     <div style="
#         background: linear-gradient(90deg, #8e44ad, #3498db);
#         padding: 30px 20px;
#         border-radius: 25px;
#         box-shadow: 0 7px 6px rgba(0, 0, 0, 0.3);
#         display: inline-block;
#         border: 2px solid #CCCCFF;
#         max-width: 90%;
#     ">
#         <span style="
#             color: #FFBF00;
#             font-size: 25px;
#             font-family: Cooper Black;
#             letter-spacing: 2px;
#             line-height: 1.4;
#             font-weight: bold;
#             text-transform: uppercase;
#             text-shadow: 3px 3px 8px rgba(0, 0, 0, 0.5);
#         ">
#             LAB NO 11
#         </span>
#     </div>
# </center>  </div>
# </center>
#   </div>
# </center>

# %% [markdown]
# <span style="color: #000000;
# font-size: 44px;
# transition: color 0.3s;">&#x21DD; </span>
# <span style="color: #ff0000;
#     font-family: Arial Black;
# font-size: 35px; font-weight: bold;
# text-shadow: 0px 4px 2px rgb(0, 0, 0);">
#     Lab Work Tasks :</span>

# %% [markdown]
# <center><span style="color:blue;
# font-family:Algerian;
# font-weight:bold;
# font-size:35px;"><center><span style="color:blue;
# font-family:Algerian;
# font-weight:bold;
# font-size:35px;"><center><span style="color:blue;
# font-family:Algerian;
# font-weight:bold;
# font-size:35px;">IMPLEMENTATION OF STACKS IN PYTHON:  </span></center> </span></center> </span></center>

# %% [markdown]
# <center><span style="color:green;
# font-family:Matura MT Script Capitals;
# font-weight:bold;
# font-size:35px;">1. List Stack:</span></center

# %% [markdown]
# ![lab 11www.PNG](attachment:58905c42-4b02-48a0-95ee-0ce41f42adec.PNG)

# %%
class StackList:
    def __init__(self):
        self.items = []

    def is_empty(self):
        return len(self.items) == 0

    def push(self, item):
        self.items.append(item)

    def pop(self):
        if not self.is_empty():
            return self.items.pop()
        else:
            print("Stack is empty")

    def peek(self):
        if not self.is_empty():
            return self.items[-1]
        else:
            print("Stack is empty")

    def size(self):
        return len(self.items)

# %%
# Example usage:
stack = StackList()

# %%
# Push different data types
stack.push(42)        # Integer
stack.push("Python")  # String
stack.push([5, 10])   # List

# %%
# Display the top item using peek
print("Top item:", stack.peek())
# Out:
# Top item: [5, 10]

# %%
# Display the size of the stack
print("Stack size:", stack.size())
# Out:
# Stack size: 3

# %%
# Pop items and display the top item and size
print("Popped:", stack.pop())
print("Top item:", stack.peek())
print("Stack size:", stack.size())
# Out:
# Popped: [5, 10]
# Top item: Python
# Stack size: 2

# %% [markdown]
# <center><span style="color:green;
# font-family:Matura MT Script Capitals;
# font-weight:bold;
# font-size:35px;">2. Creating object of this class: :</span></center

# %% [markdown]
# ![LOKJHGFDRETYUHB.PNG](attachment:dcd82b36-57df-42ec-9029-6b9a3d3f285f.PNG)

# %%
class StackList:

    def __init__(self):
        self.items = []

    def is_empty(self):
        return len(self.items) == 0

    def push(self, item):
        self.items.append(item)

    def pop(self):
        if not self.is_empty():
            return self.items.pop()
        else:
            print("Stack is empty")
            return None

    def peek(self):
        if not self.is_empty():
            return self.items[-1]
        else:
            print("Stack is empty")
            return None

    def size(self):
        return len(self.items)

# %%
# Example usage:
stack = StackList()
stack.push(1)
stack.push(2)
stack.push(3)

# %%
print("Pop:", stack.pop())  # Output: Pop: 3
print("Peek:", stack.peek())  # Output: Peek: 2
print("Stack size:", stack.size())  # Output: Stack size: 2
# Out:
# Pop: 3
# Peek: 2
# Stack size: 2

# %% [markdown]
# <center><span style="color:green;
# font-family:Matura MT Script Capitals;
# font-weight:bold;
# font-size:35px;">1. Deque Implementation: </span></center

# %% [markdown]
# ![lab 1111111111111111.PNG](attachment:fb0052d7-67a5-48ce-9acf-56bbd12d3e9e.PNG)

# %%
from collections import deque

class StackDeque:
    def __init__(self):
        self.items = deque()

    def is_empty(self):
        return len(self.items) == 0

    def push(self, item):
        self.items.append(item)

    def pop(self):
        if not self.is_empty():
            return self.items.pop()
        else:
            print("Stack is empty")
            return None

    def peek(self):
        if not self.is_empty():
            return self.items[-1]
        else:
            print("Stack is empty")
            return None

    def size(self):
        return len(self.items)

# %%
# Creating instances of DequeStack
stack1 = StackDeque()
stack2 = StackDeque()

# %% [markdown]
# <center><span style="color:green;
# font-family:Matura MT Script Capitals;
# font-weight:bold;
# font-size:35px;">b. Pushing element in Stack </span></center

# %% [markdown]
# ![OLOL.PNG](attachment:0fc21630-fb66-49de-9b31-69e86d5bb5a4.PNG)

# %%
from collections import deque

class StackDeque:
    
    def __init__(self):
        self.stack = deque()

    def push(self, item):
        self.stack.append(item)

    def pop(self):
        if not self.is_empty():
            return self.stack.pop()
        else:
            print("Stack is empty")
            return None

    def peek(self):
        if not self.is_empty():
            return self.stack[-1]
        else:
            print("Stack is empty")
            return None

    def size(self):
        return len(self.stack)

    def is_empty(self):
        return len(self.stack) == 0

# %%
# Creating instances of DequeStack
stack1 = StackDeque()
stack2 = StackDeque()

# %%
# Pushing elements onto stack1
stack1.push(1)
stack1.push(2)
stack1.push(3)

# %%
# Pushing elements onto stack2
stack2.push("apple")
stack2.push("banana")
stack2.push("cherry")

# %%
# Printing the state of both stacks
print("Stack1:", stack1.stack)
print("Stack2:", stack2.stack)
# Out:
# Stack1: deque([1, 2, 3])
# Stack2: deque(['apple', 'banana', 'cherry'])

# %% [markdown]
# <center><span style="color:green;
# font-family:Matura MT Script Capitals;
# font-weight:bold;
# font-size:35px;">c. Popping out element from Stack. </span></center

# %% [markdown]
# ![mamon.PNG](attachment:d65b8875-0e2b-4cad-af2a-792999434510.PNG)

# %%
from collections import deque

class StackDeque:
    def __init__(self):
        self.stack = deque()

    def push(self, item):
        self.stack.append(item)

    def pop(self):
        if not self.is_empty():
            return self.stack.pop()
        else:
            print("Stack is empty")
            return None

    def peek(self):
        if not self.is_empty():
            return self.stack[-1]
        else:
            print("Stack is empty")
            return None

    def size(self):
        return len(self.stack)

    def is_empty(self):
        return len(self.stack) == 0

# %%
# Creating instances of DequeStack
stack1 = StackDeque()
stack2 = StackDeque()

# %%
# Pushing elements onto stack1
stack1.push(1)
stack1.push(2)
stack1.push(3)

# %%
# Pushing elements onto stack2
stack2.push("apple")
stack2.push("banana")
stack2.push("cherry")

# %%
# Popping elements from stack1
popped1 = stack1.pop()
popped2 = stack1.pop()

# %%
# Popping elements from stack2
popped3 = stack2.pop()
popped4 = stack2.pop()

# %%
# Checking the popped elements and the current state of both stacks
print("Popped from Stack1:", popped1, popped2)
print("Popped from Stack2:", popped3, popped4)
print("Current Stack1:", stack1.stack)
print("Current Stack2:", stack2.stack)
# Out:
# Popped from Stack1: 3 2
# Popped from Stack2: cherry banana
# Current Stack1: deque([1])
# Current Stack2: deque(['apple'])

# %%
print("\nDifference between Deque and List Implementation of Stack:")
print("{:<25} | {:<30}".format("Deque", "List"))
print("{:<25} | {:<30}".format("Deques are optimized for fast appends and pops from both ends, making them more efficient than lists for implementing stacks.", "Lists are a built-in data type in Python and are versatile."))
print("{:<25} | {:<30}".format("Appending and popping elements from both ends of a deque is O(1) time on average.", "List operations, such as indexing, are generally O(1)."))
print("{:<25} | {:<30}".format("Deques are slightly more memory-intensive than lists.", "Appending and popping elements from the end of a list (used as a stack) takes O(1) time on average, but occasionally O(n) time when the list needs to be resized."))
# Out:
# Difference between Deque and List Implementation of Stack:
# Deque                     | List
# Deques are optimized for fast appends and pops from both ends, making them more efficient than lists for implementing stacks. | Lists are a built-in data type in Python and are versatile.
# Appending and popping elements from both ends of a deque is O(1) time on average. | List operations, such as indexing, are generally O(1).
# Deques are slightly more memory-intensive than lists. | Appending and popping elements from the end of a list (used as a stack) takes O(1) time on average, but occasionally O(n) time when the list needs to be resized.

# %% [markdown]
# ![qn1.PNG](attachment:6ec21544-1121-4c26-a6fc-b695a82acdfc.PNG)

# %% [markdown]
# ![qn2.PNG](attachment:bc987bfb-7d3c-4e0f-b722-cec0531aeca7.PNG)

# %% [markdown]
# <center><span style="color:blue;
# font-family:Algerian;
# font-weight:bold;
# font-size:35px;">2. NODE BASE IMPLEMENTATION: </span></center>

# %% [markdown]
# ![t11.PNG](attachment:e8aaae83-5923-4528-be28-f5eb2e5e363f.PNG)

# %%
class Node:
    """
    Represents a single node in the linked list.
    """

    def __init__(self, data):
        """
        Initializes a node with the given data.

        Args:
            data: The value to be stored in the node.
        """
        self.data = data
        self.next = None

# %% [markdown]
# ![t22.PNG](attachment:bf09eb6e-4d7f-463e-9781-017bae7e65b1.PNG)

# %%
class NodeStack:
    """
    Implements a stack using a linked list of nodes.
    """

    def __init__(self):
        """
        Initializes an empty stack with the top pointer set to None.
        """
        self.top = None

# %% [markdown]
# ![t33.PNG](attachment:92572273-172a-4cc0-b46b-dc8fbb98eff6.PNG)

# %%
   def push(self, item):
        """
        Adds an item to the top of the stack.

        Args:
            item: The item to be added to the stack.
        """
        new_node = Node(item)
        new_node.next = self.top
        self.top = new_node

# %% [markdown]
# ![t33.PNG](attachment:710a824b-a7d0-4e01-95a3-4b785fbab7c4.PNG)

# %%
   def pop(self):
        """
        Removes and returns the item from the top of the stack.

        Returns:
            The item at the top of the stack if the stack is not empty,
            otherwise prints an error message and returns None.
        """
        if not self.is_empty():
            popped_item = self.top.data
            self.top = self.top.next
            return popped_item
        else:
            print("Stack is empty")
            return None

# %% [markdown]
# ![t44.PNG](attachment:7961a497-4247-453f-81ed-0864ceefb596.PNG)

# %%
    def peek(self):
        """
        Returns the item at the top of the stack without removing it.

        Returns:
            The item at the top of the stack if the stack is not empty,
            otherwise prints an error message and returns None.
        """
        if not self.is_empty():
            return self.top.data
        else:
            print("Stack is empty")
            return None

# %% [markdown]
# ![t5.PNG](attachment:e164f135-1365-420a-8ea9-6b0efb4a8504.PNG)

# %%
    def size(self):
        """
        Calculates the number of elements in the stack by traversing the linked nodes.

        Returns:
            int: The number of elements in the stack.
        """
        current = self.top
        count = 0
        while current:
            count += 1
            current = current.next
        return count

    def is_empty(self):
        """
        Checks if the stack is empty.

        Returns:
            bool: True if the stack is empty, False otherwise.
        """
        return self.top is None

# %%
# Example usage
if __name__ == "__main__":
    stack = NodeStack()
    stack.push(1)
    stack.push(2)
    stack.push(3)

    print("Popped element:", stack.pop())
    print("Top element:", stack.peek())
    print("Stack size:", stack.size())
# Out:
# Popped element: 3
# Top element: 2
# Stack size: 2

# %% [markdown]
# ![ololo.PNG](attachment:23edc419-4ffd-44d5-a993-dede0e565e42.PNG)

# %%
# Creating an instance of NodeStack
stack = NodeStack()

# Pushing elements onto the stack
stack.push(1)
stack.push(2)
stack.push(3)

# Performing operations on the stack
print("Peek:", stack.peek())  # Output: Peek: 3
print("Pop:", stack.pop())    # Output: Pop: 3
print("Stack size:", stack.size())  # Output: Stack size: 2
# Out:
# Peek: 3
# Pop: 3
# Stack size: 2
