# %% [markdown]
# <center>
#     <div style="
#         background: linear-gradient(90deg, #8e44ad, #3498db);
#         padding: 30px 20px;
#         border-radius: 25px;
#         box-shadow: 0 7px 6px rgba(0, 0, 0, 0.3);
#         display: inline-block;
#         border: 2px solid #CCCCFF;
#         max-width: 90%;
#     ">
#         <span style="
#             color: #FFBF00;
#             font-size: 25px;
#             font-family: Cooper Black;
#             letter-spacing: 2px;
#             line-height: 1.4;
#             font-weight: bold;
#             text-transform: uppercase;
#             text-shadow: 3px 3px 8px rgba(0, 0, 0, 0.5);
#         ">
#             LAB NO 08
#         </span>
#     </div>
# </center>  </div>
# </center>
#   </div>
# </center>

# %% [markdown]
# ![lab n0 8 task 1.PNG](attachment:d4d9aa13-bdea-42bc-8f9f-7ec61561ae85.PNG)

# %%
# Define the Rectangle class
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Define the Square class that inherits from Rectangle
class Square(Rectangle):
    def __init__(self, side):
        super().__init__(side, side)

# Define the Cube class that inherits from Square
class Cube(Square):
    def __init__(self, side):
        super().__init__(side)

    def area(self):
        # Surface area of a cube: 6 * (side^2)
        return 6 * super().area()

    def volume(self):
        # Volume of a cube: side^3
        return self.length ** 3

# %%
cube1 = Cube(3)
cube2 = Cube(4)

# %%
print("Cube 1:")
print("Surface Area:", cube1.area())
print("Volume:", cube1.volume())
# Out:
# Cube 1:
# Surface Area: 54
# Volume: 27

# %%
print("\nCube 2:")
print("Surface Area:", cube2.area())
print("Volume:", cube2.volume())
# Out:
# Cube 2:
# Surface Area: 96
# Volume: 64

# %% [markdown]
# ![NOW 4.PNG](attachment:81f6b93c-248f-4692-99b6-8be343d91bb7.PNG)

# %%
# Base Employee Class
class Employee:
    def __init__(self, employee_id, name):
        self.id = employee_id
        self.name = name
        
    def calculate_payroll(self):
        raise NotImplementedError("This method should be overridden in the subclass")

# SalaryEmployee Class (Administrative Workers)
class SalaryEmployee(Employee):
    def __init__(self, employee_id, name, weekly_salary):
        # Initialize the base class with id and name
        super().__init__(employee_id, name)
        self.weekly_salary = weekly_salary
    
    def calculate_payroll(self):
        return self.weekly_salary

# %%
# Manager Class (inherits from SalaryEmployee)
class Manager(SalaryEmployee):
    def __init__(self, emp_id, name, weekly_salary):
        super().__init__(emp_id, name, weekly_salary)
    
    def work(self, hours):
        print(f"Manager {self.name} worked for {hours} hours, delegating tasks and overseeing operations.")

# Secretary Class (inherits from SalaryEmployee)
class Secretary(SalaryEmployee):
    def __init__(self, emp_id, name, weekly_salary):
        super().__init__(emp_id, name, weekly_salary)
    
    def work(self, hours):
        print(f"Secretary {self.name} worked for {hours} hours, handling paperwork and administration.")

# SalesPerson Class (inherits from SalaryEmployee)
class SalesPerson(SalaryEmployee):
    def __init__(self, emp_id, name, weekly_salary, commission_rate):
        super().__init__(emp_id, name, weekly_salary)
        self.commission_rate = commission_rate  
        self.sales_made = 0  

    def work(self, hours, sales_made):
        self.sales_made += sales_made
        commission = sales_made * self.commission_rate
        total_pay = self.weekly_salary + commission
        print(f"SalesPerson {self.name} worked for {hours} hours and made {sales_made} in sales. "
              f"Commission earned: {commission}. Total Pay: {total_pay:.2f}")

# HourlyEmployee Class (inherits from Employee)
class Factoryworker(Employee):
    def __init__(self, emp_id, name, hourly_rate, hours_worked):
        super().__init__(emp_id, name)
        self.hourly_rate = hourly_rate
        self.hours_worked = hours_worked
    
    def calculate_payroll(self):
        return self.hourly_rate * self.hours_worked
    
    def work(self, hours):
        self.hours_worked += hours
        total_pay = self.calculate_payroll()
        print(f"Factory Worker {self.name} worked for {hours} hours. Total Pay: {total_pay:.2f}")

# ProductivitySystem Class
class ProductivitySystem:
    def calculate_productivity(self, employees):
        for employee in employees:
            print(f"Employee: {employee.name}")
            if isinstance(employee, SalesPerson):
                # SalesPerson needs to specify hours worked and sales made
                employee.work(40, 2000)  
            else:
                employee.work(40)  
            print("=" * 40)
class PayrollSystem:
    def calculate_payroll(self, employees):
        for employee in employees:
            payroll = employee.calculate_payroll()
            print(f"Employee ID: {employee.id}, Name: {employee.name}, Payroll: {payroll:.2f}")
            print("=" * 40)

# %%
manager = Manager("DANISH", 80000)
secretary = Secretary("AHMAD YAR", 40000)
salesperson = SalesPerson("HAMMAD", 50000, 0.05)
factory_worker = FactoryWorker("JAVED", 20)

# %%
employees = [manager, secretary, salesperson, factory_worker]

# %%
print("Productivity Tracking:")
ProductivitySystem.track(employees, 8)
# Out:
# Productivity Tracking:
# DANISH worked for 8 hours managing the team and yelling at people.
# AHMAD YAR worked for 8 hours doing paperwork and keeping things organized.
# HAMMAD worked for 8 hours making sales calls.
# JAVED worked for 8 hours manufacturing products.

# %%
print("\nAdditional Calculations:")
print(f"{salesperson.name} earned a commission of ${salesperson.calculate_commission(2000):.2f}.")
print(f"{factory_worker.name} earned ${factory_worker.calculate_pay(8):.2f} for 8 hours of work.")
# Out:
# Additional Calculations:
# HAMMAD earned a commission of $100.00.
# JAVED earned $160.00 for 8 hours of work.

# %% [markdown]
# ![NOW 5.PNG](attachment:2ba17a21-8cec-4bf0-a87e-c2154f2b029e.PNG)

# %%
class Staff:
    def __init__(self, name, staff_id):
        self.name = name
        self.staff_id = staff_id

    def get_details(self):
        return f"Name: {self.name}, ID: {self.staff_id}"


class AdminStaff(Staff):
    def __init__(self, name, staff_id, role):
        super().__init__(name, staff_id)
        self.role = role

    def get_details(self):
        return f"{super().get_details()}, Role: {self.role}"


class FacultyStaff(Staff):
    def __init__(self, name, staff_id, designation):
        super().__init__(name, staff_id)
        self.designation = designation

    def get_details(self):
        return f"{super().get_details()}, Designation: {self.designation}"


class Lecturer(FacultyStaff):
    def __init__(self, name, staff_id):
        super().__init__(name, staff_id, "Lecturer")

class AssistantProfessor(FacultyStaff):
    def __init__(self, name, staff_id):
        super().__init__(name, staff_id, "Assistant Professor")

class AssociateProfessor(FacultyStaff):
    def __init__(self, name, staff_id):
        super().__init__(name, staff_id, "Associate Professor")

class Professor(FacultyStaff):
    def __init__(self, name, staff_id):
        super().__init__(name, staff_id, "Professor")


class LabEngineer(AdminStaff):
    def __init__(self, name, staff_id):
        super().__init__(name, staff_id, "Lab Engineer")

class LabTechnician(AdminStaff):
    def __init__(self, name, staff_id):
        super().__init__(name, staff_id, "Lab Technician")

class LabAssistant(AdminStaff):
    def __init__(self, name, staff_id):
        super().__init__(name, staff_id, "Lab Assistant")

class LabAttendant(AdminStaff):
    def __init__(self, name, staff_id):
        super().__init__(name, staff_id, "Lab Attendant")

# %%
 if __name__ == "__main__":
    lecturer = Lecturer("DANISH", 101)
    assistant_professor = AssistantProfessor("AHMAD YAR", 102)
    associate_professor = AssociateProfessor("JAVED", 103)
    professor = Professor("HAMMAD", 104)

# %%
    
    lab_engineer = LabEngineer("MARCO", 201)
    lab_technician = LabTechnician("KGF", 202)
    lab_assistant = LabAssistant("SALAR", 203)
    lab_attendant = LabAttendant("DEVARA", 204)

# %%
    
    staff_list = [
        lecturer,
        assistant_professor,
        associate_professor,
        professor,
        lab_engineer,
        lab_technician,
        lab_assistant,
        lab_attendant,
    ]

# %%
    print("Electrical Department Staff Details:")
    for staff in staff_list:
        print(staff.get_details())
# Out:
# Electrical Department Staff Details:
# Name: DANISH, ID: 101, Designation: Lecturer
# Name: AHMAD YAR, ID: 102, Designation: Assistant Professor
# Name: JAVED, ID: 103, Designation: Associate Professor
# Name: HAMMAD, ID: 104, Designation: Professor
# Name: MARCO, ID: 201, Role: Lab Engineer
# Name: KGF, ID: 202, Role: Lab Technician
# Name: SALAR, ID: 203, Role: Lab Assistant
# Name: DEVARA, ID: 204, Role: Lab Attendant
